# %%
import pandas as pd

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
d = pd.DataFrame(data=d)
d
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
a=list(a)

# %%
a
# Out:
# ['col1', 'col2']

# %%
b= ["col1", "col3"]

# %%
for i in b: 
    if i not in a:
        print("MIERDA")
# Out:
# MIERDA

# %%
def checker(lista, lista2):
    assert ("col1" not in lista), "cacafuti!"
    return ("yassss")

# %%
checker (a, b)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-af6d3f3421b0> in <module>
# ----> 1 checker (a, b)
#
# <ipython-input-22-c48c092e00e4> in checker(lista, lista2)
#       1 def checker(lista, lista2):
# ----> 2     assert ("col1" not in lista), "cacafuti!"
#       3     return ("yassss")
#
# AssertionError: cacafuti!

# %%
list()
# Out:
# True

# %%
d
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
d['e'] = Series(np.random.randn(sLength), index=d.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2dbbaabf458c> in <module>
# ----> 1 d['e'] = Series(np.random.randn(sLength), index=d.index)
#
# NameError: name 'Series' is not defined

# %%
import numpy as np

# %%
d.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
d["g"]=0
d
# Out:
#    col1  col2  e  g
# 0     1     3  4  0
# 1     2     4  4  0

# %%
import geopandas.geoseries

p1 = Point(.5,.5)
p2 = Point(.5,1)
p3 = Point(1,1)

g1 = geopandas.GeoSeries([p1,p2,p3])
g2 = geopandas.GeoSeries([p2,p3])

g = geopandas.GeoSeries([Polygon([(0,0), (0,2), (2,2), (2,0)])])

poly = geopandas.GeoSeries(Polygon([(0,0), (0,2), (2,2), (2,0)]))
g1.intersects(poly.loc[0])
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
x=geopandas.read_file(r"C:\Users\usuario\Desktop\Master WAGENINGEN\Asignaturas\14_Internship\own research\GIS\Community Districts\geo_export_70d81ba7-b046-45be-8f94-aca47f71a694.shp")

# %%
x.plot()
#y= geopandas.GeoSeries.centroid(x)
centroids = x.centroid
centroids.plot()

# %%
def intersect_counter(centroids, boundaries):
    boundaries["count"] = 0
    for i in range(len(boundaries)):
        CD = boundaries.loc[[i]]
        inter_count = sum(centroids.intersects(CD))
        boundaries.loc[i,"count"] = inter_count
        inter_count=0
    return boundaries

# %%
subset = x.loc[0]
print(subset)
subset.plot()
# Out:
# shape_leng                                              51549.6
# shape_area                                          1.03178e+08
# boro_cd                                                     311
# geometry      POLYGON ((-73.97299433938896 40.60881414180224...
# Name: 0, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-037d8a38b90d> in <module>
#       1 subset = x.loc[0]
#       2 print(subset)
# ----> 3 subset.plot()
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# ...

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
caca = world.loc[[1]]

caca.plot()
caca
# Out:
#       pop_est continent    name iso_a3  gdp_md_est  \
# 1  12799293.0    Africa  Angola    AGO    110300.0
#
#                                             geometry
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...

# %%
d
# Out:
#    col1  col2  e  g
# 0     1     3  4  0
# 1     2     4  4  0

# %%
d.loc[0,"col1"] = 888888

# %%
d
# Out:
#      col1  col2  e  g
# 0  888888     3  4  0
# 1       2     4  4  0

# %%
x= intersect_counter(centroids, x)
x
# Out:
#        shape_leng    shape_area  boro_cd  \
# 0    51549.557886  1.031778e+08    311.0
# 1    65821.999543  8.819584e+07    313.0
# 2    52245.830489  9.952550e+07    312.0
# 3    37008.100320  5.666322e+07    304.0
# 4    62239.832144  1.142663e+08    209.0
# 5    83998.355422  1.548966e+08    212.0
# 6    35875.711172  4.266431e+07    206.0
# 7    47817.454835  9.207172e+07    208.0
# 8    32820.398590  5.056641e+07    226.0
# 9    43326.850619  9.381021e+07    317.0
# 10   53561.206016  5.516890e+07    108.0
# 11   37018.373446  6.573966e+07    404.0
# 12  211896.803871  1.957196e+08    414.0
# 13  247815.353738  1.237801e+08    484.0
# 14   45740.884075  1.003130e+08    211.0
# 15   28391.594231  3.143260e+07    227.0
# 16   32997.574975  5.176891e+07    316.0
# 17   65928.410985  2.673333e+08    412.0
# 18   70005.252394  2.103957e+08    405.0
# 19   42672.563130  3.872854e+07    106.0
# 20   42759.622669  8.270025e+07    406.0
# 21   29416.378444  3.831703e+07    205.0
# ...
